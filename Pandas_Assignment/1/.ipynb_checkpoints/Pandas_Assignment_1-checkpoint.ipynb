# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
# using the glob libraary to read all csv files
census_data = glob.glob('states[0-9].csv') # states*.csv and states?csv also work
census_data                                #now we have a list of all the files
# Out:
# ['states1.csv',
#  'states3.csv',
#  'states4.csv',
#  'states5.csv',
#  'states8.csv',
#  'states0.csv',
#  'states6.csv',
#  'states7.csv',
#  'states2.csv',
#  'states9.csv']

# %%
combined_data = []                      #storing all files in one variable
for all_files in census_data:
    raw_data = pd.read_csv(all_files)
    combined_data.append(raw_data)
combined_data
# Out:
# [   Unnamed: 0                 State  TotalPop             Hispanic  \
#  0           0              Colorado   5278906   20.78438003220608%
#  1           1           Connecticut   3593222  15.604830917874388%
#  2           2              Delaware    926454    8.82476635514019%
#  3           3  District of Columbia    647484   9.165921787709499%
#  4           4               Florida  19645772    21.3385426653884%
#  5           5               Georgia  10006693   8.418242207460397%
#
#                   White                Black                Native  \
#  0   69.89557165861504%   3.546376811594201%   0.5738325281803548%
#  1    67.6770531400966%   10.34806763285027%  0.12620772946859898%
#  2   64.63271028037383%  20.743925233644834%  0.25981308411214965%
#  3  33.103910614525134%   51.77653631284915%  0.20055865921787713%
#  4   59.08374880153398%  15.165675934803444%   0.2104506232023015%
#  5   54.28630556974962%   32.08829841594277%  0.18758303525804798%
#
# ...

# %%
us_census = pd.concat(combined_data,  ignore_index=True) 
us_census.head()
# Out:
#    Unnamed: 0                 State  TotalPop             Hispanic  \
# 0           0              Colorado   5278906   20.78438003220608%
# 1           1           Connecticut   3593222  15.604830917874388%
# 2           2              Delaware    926454    8.82476635514019%
# 3           3  District of Columbia    647484   9.165921787709499%
# 4           4               Florida  19645772    21.3385426653884%
#
#                  White                Black                Native  \
# 0   69.89557165861504%   3.546376811594201%   0.5738325281803548%
# 1    67.6770531400966%   10.34806763285027%  0.12620772946859898%
# 2   64.63271028037383%  20.743925233644834%  0.25981308411214965%
# 3  33.103910614525134%   51.77653631284915%  0.20055865921787713%
# 4   59.08374880153398%  15.165675934803444%   0.2104506232023015%
#
#                  Asian                Pacific               Income  \
# 0   2.661996779388082%                    NaN  $64657.801787164906
# ...

# %%
us_census.drop('Unnamed: 0', inplace=True, axis=1) #reomving the Unnamed column

# %%
us_census.head()
# Out:
#                   State  TotalPop             Hispanic                White  \
# 0              Colorado   5278906   20.78438003220608%   69.89557165861504%
# 1           Connecticut   3593222  15.604830917874388%    67.6770531400966%
# 2              Delaware    926454    8.82476635514019%   64.63271028037383%
# 3  District of Columbia    647484   9.165921787709499%  33.103910614525134%
# 4               Florida  19645772    21.3385426653884%   59.08374880153398%
#
#                  Black                Native                Asian  \
# 0   3.546376811594201%   0.5738325281803548%   2.661996779388082%
# 1   10.34806763285027%  0.12620772946859898%   4.021980676328502%
# 2  20.743925233644834%  0.25981308411214965%  3.2686915887850483%
# 3   51.77653631284915%  0.20055865921787713%  3.3832402234636865%
# 4  15.165675934803444%   0.2104506232023015%  2.2831735378715257%
#
#                  Pacific               Income           GenderPop
# ...

# %%
us_census['Income'] = us_census['Income'].replace(['\$,'],'', regex=True) # Reomving the dollar sign
us_census.head()
# Out:
#                   State  TotalPop             Hispanic                White  \
# 0              Colorado   5278906   20.78438003220608%   69.89557165861504%
# 1           Connecticut   3593222  15.604830917874388%    67.6770531400966%
# 2              Delaware    926454    8.82476635514019%   64.63271028037383%
# 3  District of Columbia    647484   9.165921787709499%  33.103910614525134%
# 4               Florida  19645772    21.3385426653884%   59.08374880153398%
#
#                  Black                Native                Asian  \
# 0   3.546376811594201%   0.5738325281803548%   2.661996779388082%
# 1   10.34806763285027%  0.12620772946859898%   4.021980676328502%
# 2  20.743925233644834%  0.25981308411214965%  3.2686915887850483%
# 3   51.77653631284915%  0.20055865921787713%  3.3832402234636865%
# 4  15.165675934803444%   0.2104506232023015%  2.2831735378715257%
#
#                  Pacific              Income           GenderPop
# ...

# %%
us_census['Income'] = pd.to_numeric(us_census.Income)  #converting string into a number

# %%
us_census.Income.head()
# Out:
# 0    64657.801787
# 1    76146.560588
# 2    61827.976636
# 3    75466.363636
# 4    50690.194987
# Name: Income, dtype: float64

# %%
us_census['Income'].head()
# Out:
# 0    64657.801787
# 1    76146.560588
# 2    61827.976636
# 3    75466.363636
# 4    50690.194987
# Name: Income, dtype: float64

# %%
us_census['Men'] = us_census['GenderPop'].str.split('(_)',expand=True)[0]     #spliting genderprop into two columns
us_census['Women'] = us_census['GenderPop'].str.split('(_)',expand=True)[2]
us_census.head()
# Out:
#                   State  TotalPop             Hispanic                White  \
# 0              Colorado   5278906   20.78438003220608%   69.89557165861504%
# 1           Connecticut   3593222  15.604830917874388%    67.6770531400966%
# 2              Delaware    926454    8.82476635514019%   64.63271028037383%
# 3  District of Columbia    647484   9.165921787709499%  33.103910614525134%
# 4               Florida  19645772    21.3385426653884%   59.08374880153398%
#
#                  Black                Native                Asian  \
# 0   3.546376811594201%   0.5738325281803548%   2.661996779388082%
# 1   10.34806763285027%  0.12620772946859898%   4.021980676328502%
# 2  20.743925233644834%  0.25981308411214965%  3.2686915887850483%
# 3   51.77653631284915%  0.20055865921787713%  3.3832402234636865%
# 4  15.165675934803444%   0.2104506232023015%  2.2831735378715257%
#
#                  Pacific        Income           GenderPop       Men  \
# ...

# %%
us_census['Men'] = us_census['Men'].replace(['M'],'', regex=True)       #removing M anf F and converting into numeric data 
us_census['Women'] = us_census['Women'].replace(['F'],'', regex=True)
us_census['Men'] = pd.to_numeric(us_census.Men)
us_census['Women'] = pd.to_numeric(us_census.Women)
us_census.head()
# Out:
#                   State  TotalPop             Hispanic                White  \
# 0              Colorado   5278906   20.78438003220608%   69.89557165861504%
# 1           Connecticut   3593222  15.604830917874388%    67.6770531400966%
# 2              Delaware    926454    8.82476635514019%   64.63271028037383%
# 3  District of Columbia    647484   9.165921787709499%  33.103910614525134%
# 4               Florida  19645772    21.3385426653884%   59.08374880153398%
#
#                  Black                Native                Asian  \
# 0   3.546376811594201%   0.5738325281803548%   2.661996779388082%
# 1   10.34806763285027%  0.12620772946859898%   4.021980676328502%
# 2  20.743925233644834%  0.25981308411214965%  3.2686915887850483%
# 3   51.77653631284915%  0.20055865921787713%  3.3832402234636865%
# 4  15.165675934803444%   0.2104506232023015%  2.2831735378715257%
#
#                  Pacific        Income           GenderPop      Men  \
# ...

# %%
#Plotting Men's and Women's Income
plt.scatter(us_census.Women,us_census.Income)
plt.xlabel('Women')
plt.ylabel('Income')
plt.show()

# %%
plt.clf()
print(us_census['Women'])
# Out:
# 0      2630239.0
# 1      1841615.0
# 2       478041.0
# 3       340810.0
# 4     10045763.0
# 5      5123362.0
# 6      1558931.0
# 7      1453125.0
# 8      2233145.0
# 9      2364097.0
# 10      679019.0
# 11           NaN
# 12           NaN
# 13     3455936.0
# 14     5038598.0
# 15     2727005.0
# 16     1536358.0
# 17     3081445.0
# 18     3081445.0
# 19           NaN
# 20      939759.0
# 21     1390901.0
# 22      670717.0
# 23     4561386.0
# 24      543273.0
# 25     2455167.0
# 26      419713.0
# 27     3331859.0
# 28    13367298.0
# 29     1444150.0
# 30     2489527.0
# 31      349215.0
# 32     3342840.0
# 33     1506295.0
# 34    19334329.0
# 35     2630239.0
# 36     4561386.0
# 37     1051703.0
# 38    10131373.0
# 39     5049925.0
# 40      353677.0
# 41     5913084.0
# 42     5913084.0
# 43     1942789.0
# 44     1990780.0
# 45     6534215.0
# 46     1869213.0
# 47      543273.0
# 48     5123362.0
# 49      696428.0
# 50      806083.0
# 51     6556862.0
# ...

# %%
#Replace the Women's Nan's values with the difference between TotalPop minus the Men's population
us_census['Women'] = us_census['Women'].fillna(us_census['TotalPop']- us_census['Men'])
print(us_census['Women'])
# Out:
# 0      2630239.0
# 1      1841615.0
# 2       478041.0
# 3       340810.0
# 4     10045763.0
# 5      5123362.0
# 6      1558931.0
# 7      1453125.0
# 8      2233145.0
# 9      2364097.0
# 10      679019.0
# 11     3057895.0
# 12     3057895.0
# 13     3455936.0
# 14     5038598.0
# 15     2727005.0
# 16     1536358.0
# 17     3081445.0
# 18     3081445.0
# 19      504536.0
# 20      939759.0
# 21     1390901.0
# 22      670717.0
# 23     4561386.0
# 24      543273.0
# 25     2455167.0
# 26      419713.0
# 27     3331859.0
# 28    13367298.0
# 29     1444150.0
# 30     2489527.0
# 31      349215.0
# 32     3342840.0
# 33     1506295.0
# 34    19334329.0
# 35     2630239.0
# 36     4561386.0
# 37     1051703.0
# 38    10131373.0
# 39     5049925.0
# 40      353677.0
# 41     5913084.0
# 42     5913084.0
# 43     1942789.0
# 44     1990780.0
# 45     6534215.0
# 46     1869213.0
# 47      543273.0
# 48     5123362.0
# 49      696428.0
# 50      806083.0
# 51     6556862.0
# ...

# %%
print(us_census.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35     True
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47     True
# 48     True
# 49    False
# 50    False
# 51    False
# 52    False
# 53     True
# 54     True
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %%
clean_us_census = us_census.drop_duplicates()  # removing duplicate values

# %%
plt.scatter(clean_us_census.Women, clean_us_census.Income) #using the scatter plot with clean values
plt.xlabel('Women')
plt.ylabel('Income')
plt.show() 
plt.clf()

# %%
clean_us_census.columns
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'GenderPop', 'Men', 'Women'],
#       dtype='object')

# %%
#clean column data. Replace a string and convert into a number.
us_census['Hispanic'] = us_census['Hispanic'].replace(['%'],'', regex=True)
us_census['White'] = us_census['White'].replace(['%'],'', regex=True)
us_census['Black'] = us_census['Black'].replace(['%'],'', regex=True)
us_census['Native'] = us_census['Native'].replace(['%'],'', regex=True)
us_census['Asian'] = us_census['Asian'].replace(['%'],'', regex=True)
us_census['Pacific'] = us_census['Pacific'].replace(['%'],'', regex=True)

us_census['Hispanic'] = pd.to_numeric(us_census.Hispanic)
us_census['White'] = pd.to_numeric(us_census.White)
us_census['Black'] = pd.to_numeric(us_census.Black)
us_census['Native'] = pd.to_numeric(us_census.Native)
us_census['Asian'] = pd.to_numeric(us_census.Asian)
us_census['Pacific'] = pd.to_numeric(us_census.Pacific)

# %%
print(us_census.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35     True
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47     True
# 48     True
# 49    False
# 50    False
# 51    False
# 52    False
# 53     True
# 54     True
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %%
clean_us_census = us_census.drop_duplicates()  # removing duplicate values

# %%
#Create functionm to plot different columns
def print_histogram(df, columns):
  for column in columns:
    plt.hist(df[column])
    plt.title('Figure : ' + column)
    plt.show()
    plt.clf()

# Create a list of columns to plot
columns = ['Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific']

# %%
print_histogram(clean_us_census, columns)
